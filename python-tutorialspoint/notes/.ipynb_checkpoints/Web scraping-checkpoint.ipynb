# %% [markdown]
# ## What is Web Scraping?
# - requests
# - BeautifulSoup
#
# Link that will be used: https://www.weather.gov

# %% [markdown]
# Web Scraping legalities - look for Terms and Conditions

# %% [markdown]
# #### Best Practices
#
# 1. Never scrape more frequently than you need to
# 2. Consider caching the contents you scrape
# 3. Build pauses into you code, by using functions like time.sleep()

# %% [markdown]
# ## The Structure of a web page

# %% [markdown]
# #### structure
#
# <html>
#     <head>
#     </head>
#     <body>
#         <p>
#             Welcome to the Python Bootcamp!
#             <a href="https://www.google.com">Google Everything!</a>
#         </p>
#         <p>
#             I hope you are enjoying the course so far!
#         </p>
#     </body>
# </html>

# %% [markdown]
# Child tag and the parent tag structure with indentations. We have sibling tags. The 'head' and 'body' tag are siblings.
