# %%
def sum_of_digits(n):    
    total = 0    
    while n > 0:
        last_digit = n % 10
        n = n // 10
        total = last_digit        
    return total
        
result = sum_of_digits(123)
# Printing the result
print(result)
# Out:
# 1

# %%
n = 123
n % 10
# Out:
# 3

# %%
123 // 10
# Out:
# 12

# %%
12 % 10
# Out:
# 2

# %%
12 // 10
# Out:
# 1

# %%
1 // 10
# Out:
# 0

# %%
result = sum_of_digits(12345)

# %%
print(result)
# Out:
# 1

# %%
5 * 0.621371
# Out:
# 3.106855

# %%
import math

# %%
print (math.pi)
# Out:
# 3.141592653589793
