# %%
my_dict = {'custard': 2.99, 'banana': 0.69, 'bread': 2.5, 'pear': 0.99}

# %%
'custard' in my_dict
# Out:
# True

# %%
'grapes' in my_dict
# Out:
# False

# %%
'grapes' not in my_dict
# Out:
# True

# %%
len(my_dict)
# Out:
# 4

# %%
sorted(my_dict)
# Out:
# ['banana', 'bread', 'custard', 'pear']

# %%
all(my_dict)
# Out:
# True

# %%
bool('custard')
# Out:
# True

# %%
my_dict = {'custard': 2.99, False : 0.69, 'bread': 2.5, 'pear': 0.99}

# %%
all(my_dict)
# Out:
# False

# %%
any(my_dict)
# Out:
# True
